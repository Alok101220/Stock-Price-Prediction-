# %%
import pandas as pd

# %%
APL=pd.read_csv("APPLE.csv")
MSFT=pd.read_csv("MICROSOFT.csv")
GSL=pd.read_csv("GOOGLE.csv")
AMZN=pd.read_csv("AMAZON.csv")
TSL=pd.read_csv("TESLA.csv")

# %%
APL.head()
# Out:
#          Date  Close/Last     Volume    Open    High     Low
# 0  03/30/2022      177.77   92633150  178.55  179.61  176.70
# 1  03/29/2022      178.96  100589400  176.69  179.01  176.34
# 2  03/28/2022      175.60   90371920  172.17  175.73  172.00
# 3  03/25/2022      174.72   80546160  173.88  175.28  172.75
# 4  03/24/2022      174.07   90131420  171.06  174.14  170.21

# %%
APL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1259 non-null   object
#  1   Close/Last  1259 non-null   float64
#  2   Volume      1259 non-null   int64
#  3   Open        1259 non-null   float64
#  4   High        1259 non-null   float64
#  5   Low         1259 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 59.1+ KB

# %%
APL.dropna(inplace=True)

# %%
APL["Date"]=pd.to_datetime(APL["Date"])
APL=APL.astype({"Open":float,"Volume":float})

# %%
APL
# Out:
#            Date  Close/Last       Volume      Open      High       Low
# 0    2022-03-30    177.7700   92633150.0  178.5500  179.6100  176.7000
# 1    2022-03-29    178.9600  100589400.0  176.6900  179.0100  176.3400
# 2    2022-03-28    175.6000   90371920.0  172.1700  175.7300  172.0000
# 3    2022-03-25    174.7200   80546160.0  173.8800  175.2800  172.7500
# 4    2022-03-24    174.0700   90131420.0  171.0600  174.1400  170.2100
# ...         ...         ...          ...       ...       ...       ...
# 1254 2017-04-06     35.9150   84524160.0   36.0725   36.1300   35.8625
# 1255 2017-04-05     36.0050  110598000.0   36.0550   36.3650   35.9525
# 1256 2017-04-04     36.1925   79461200.0   35.8125   36.2225   35.7925
# 1257 2017-04-03     35.9250   79880160.0   35.9275   36.0300   35.7625
# 1258 2017-03-31     35.9150   78305920.0   35.9300   36.0675   35.7525
#
# [1259 rows x 6 columns]

# %%
APL=APL.sort_values(by='Date',ignore_index=True)
APL=APL[APL["Date"]>='2015-01-01'].reset_index(drop=True)

# %%
APL.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  1259.000000  1.259000e+03  1259.000000  1259.000000  1259.000000
# mean     81.277400  1.200315e+08    81.209724    82.124990    80.338486
# std      44.163658  5.527013e+07    44.123712    44.678978    43.581125
# min      35.170000  4.099995e+07    35.305000    35.470000    35.015000
# 25%      43.958750  8.347058e+07    43.835000    44.312500    43.623750
# 50%      56.757500  1.053395e+08    56.812500    57.217500    56.410000
# 75%     123.465000  1.401439e+08   123.590000   124.947500   121.990000
# max     182.010000  4.268848e+08   182.630000   182.940000   179.120000

# %%
TSL.head()
# Out:
#          Date  Close/Last    Volume     Open       High        Low
# 0  03/30/2022     1093.99  19955000  1091.17  1113.9500  1084.0000
# 1  03/29/2022     1099.57  24538270  1107.99  1114.7700  1073.1100
# 2  03/28/2022     1091.84  34168690  1065.10  1097.8799  1053.6000
# 3  03/25/2022     1010.64  20677180  1008.00  1021.7999   997.3201
# 4  03/24/2022     1013.92  22973630  1009.73  1024.4900   988.8000

# %%
TSL.dropna(inplace=True)

# %%
TSL["Date"]=pd.to_datetime(TSL["Date"])
TSL=TSL.astype({"Open":float,"Volume":float})

# %%
TSL=TSL.sort_values(by="Date",ignore_index=True)
TSL.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  1259.000000  1.259000e+03  1259.000000  1259.000000  1259.000000
# mean    293.237084  4.468764e+07   293.052650   299.994871   285.994654
# std     329.200969  3.008758e+07   329.094851   337.127220   320.868721
# min      35.794000  9.800558e+06    36.220000    37.336000    35.398400
# 25%      61.707000  2.518422e+07    61.477500    62.686000    60.335000
# 50%      71.464000  3.486132e+07    71.506000    72.900000    70.400000
# 75%     604.585000  5.203715e+07   602.029000   616.535000   589.505000
# max    1229.910000  3.046938e+08  1234.410000  1243.490000  1217.000000

# %%
GSL.head()
# Out:
#          Date  Close/Last   Volume     Open     High        Low
# 0  03/30/2022     2852.89  1052319  2857.40  2869.61  2843.3600
# 1  03/29/2022     2865.00  1433921  2863.21  2883.25  2849.6800
# 2  03/28/2022     2839.00  1188654  2813.69  2839.53  2796.5627
# 3  03/25/2022     2830.43   964454  2835.08  2839.19  2793.9900
# 4  03/24/2022     2826.24  1027236  2785.45  2827.93  2760.7876

# %%
GSL.dropna(inplace=True)

# %%
GSL["Date"]=pd.to_datetime(GSL["Date"])
GSL=GSL.astype({"Open":float,"Volume":float})

# %%
GSL=GSL.sort_values(by="Date",ignore_index=True)
GSL.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  1259.000000  1.259000e+03  1259.000000  1259.000000  1259.000000
# mean   1535.730433  1.556408e+06  1534.844402  1550.429501  1520.016237
# std     637.121601  6.878766e+05   637.480718   643.353793   630.999681
# min     823.350000  3.467530e+05   821.930000   826.380000   817.020100
# 25%    1082.440000  1.126136e+06  1082.235000  1094.167500  1069.785000
# 50%    1229.150000  1.385194e+06  1228.010000  1240.560000  1216.530000
# 75%    1779.200000  1.773002e+06  1775.970000  1795.852500  1760.010000
# max    3014.180000  6.194691e+06  3037.270000  3042.000000  2997.750000

# %%
MSFT.head()
# Out:
#          Date  Close/Last    Volume    Open    High       Low
# 0  03/30/2022      313.86  28163560  313.76  315.95  311.5800
# 1  03/29/2022      315.41  30393400  313.91  315.82  309.0500
# 2  03/28/2022      310.70  29578190  304.33  310.80  304.3300
# 3  03/25/2022      303.68  22566450  305.23  305.50  299.2855
# 4  03/24/2022      304.10  24484460  299.14  304.20  298.3150

# %%
MSFT.dropna(inplace=True)

# %%
MSFT["Date"]=pd.to_datetime(MSFT["Date"])
MSFT=MSFT.astype({"Open":float,"Volume":float})

# %%
MSFT=MSFT.sort_values(by="Date",ignore_index=True)
MSFT.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  1259.000000  1.259000e+03  1259.000000  1259.000000  1259.000000
# mean    166.079126  2.913333e+07   166.027067   167.638000   164.314183
# std      79.092786  1.301695e+07    79.058487    79.850132    78.212881
# min      64.950000  7.425603e+06    65.040000    65.490000    64.850000
# 25%     101.085000  2.080553e+07   101.125000   101.805000    99.572500
# 50%     139.030000  2.586450e+07   139.440000   140.360000   137.870000
# 75%     222.505000  3.340784e+07   222.610000   224.290000   219.360000
# max     343.110000  1.109450e+08   344.620000   349.670000   342.200000

# %%
AMZN.head()
# Out:
#          Date  Close/Last   Volume     Open     High      Low
# 0  03/30/2022     3326.02  2808363  3370.19  3379.01  3310.00
# 1  03/29/2022     3386.30  3307680  3407.68  3416.63  3357.37
# 2  03/28/2022     3379.81  2992691  3299.50  3380.75  3298.00
# 3  03/25/2022     3295.47  2454275  3280.00  3307.37  3245.00
# 4  03/24/2022     3272.99  2839903  3274.99  3282.37  3201.00

# %%
AMZN.dropna(inplace=True)

# %%
AMZN["Date"]=pd.to_datetime(AMZN["Date"])
AMZN=AMZN.astype({"Open":float,"Volume":float})

# %%
AMZN=AMZN.sort_values(by="Date",ignore_index=True)
AMZN.describe()
# Out:
#         Close/Last        Volume         Open         High          Low
# count  1259.000000  1.259000e+03  1259.000000  1259.000000  1259.000000
# mean   2195.726485  4.291968e+06  2196.825387  2220.493205  2170.212002
# std     856.312503  2.048398e+06   857.382151   867.924808   845.890805
# min     884.670000  8.813370e+05   877.000000   890.350000   876.650000
# 25%    1602.990000  2.913494e+06  1604.000000  1623.140000  1590.795000
# 50%    1883.750000  3.701242e+06  1883.250000  1899.500000  1864.150000
# 75%    3157.485000  5.089267e+06  3159.970000  3194.284900  3120.405000
# max    3731.410000  1.654795e+07  3744.000000  3773.078200  3696.792900

# %%
Companies=[APL,TSL,GSL,MSFT,AMZN]
Companies_Title = ["Apple", "Tesla", "Google", "Microsoft", "Amazon"]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Close/Last"])
  plt.title(Companies_Title[index])
  plt.ylabel('Close/Last')

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Volume"])
  plt.title(Companies_Title[index])
  plt.ylabel('Volume')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Moving_Average_Day = [10, 20, 50]
for Moving_Average in Moving_Average_Day:
  for company in Companies:
    column_name = f'Moving Average for {Moving_Average} days'
    company[column_name] = company["Close/Last"].rolling(Moving_Average).mean()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Close/Last"])
  plt.plot(company["Date"], company["Moving Average for 10 days"])
  plt.plot(company["Date"], company["Moving Average for 20 days"])
  plt.plot(company["Date"], company["Moving Average for 50 days"])
  plt.title(Companies_Title[index])
  plt.legend(("Close/Last", "Moving Average for 10 days", "Moving Average for 20 days", "Moving Average for 50 days"))

# %%
for company in Companies:
  company["Daily Return"] = company["Close/Last"].pct_change()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Daily Return"])
  plt.title(Companies_Title[index])
  plt.ylabel('Daily Return')

# %%
plt.figure(figsize=(20, 15))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color = "purple")
  plt.title(Companies_Title[index])

# %%
Companies_returns = pd.DataFrame()
Companies_returns["AAPL"] = APL["Close/Last"]
Companies_returns["TSLA"] = TSL["Close/Last"]
Companies_returns["GOOG"] = GSL["Close/Last"]
Companies_returns["MSFT"] = MSFT["Close/Last"]
Companies_returns["AMZN"] = AMZN["Close/Last"]
Companies_returns.head()
# Out:
#       AAPL    TSLA    GOOG   MSFT    AMZN
# 0  35.9150  55.660  829.56  65.86  886.54
# 1  35.9250  59.704  838.55  65.55  891.51
# 2  36.1925  60.740  834.57  65.73  906.83
# 3  36.0050  59.000  831.41  65.56  909.28
# 4  35.9150  59.740  827.88  65.73  898.28

# %%
Companies_Daily_returns = Companies_returns.pct_change()
Companies_Daily_returns.head()
# Out:
#        AAPL      TSLA      GOOG      MSFT      AMZN
# 0       NaN       NaN       NaN       NaN       NaN
# 1  0.000278  0.072655  0.010837 -0.004707  0.005606
# 2  0.007446  0.017352 -0.004746  0.002746  0.017184
# 3 -0.005181 -0.028647 -0.003786 -0.002586  0.002702
# 4 -0.002500  0.012542 -0.004246  0.002593 -0.012097

# %%
sns.heatmap(Companies_returns.corr(), annot=True, cmap="YlGnBu")

# %%
sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="YlGnBu")

# %%
Returns = Companies_Daily_returns.dropna()

plt.figure(figsize=(20, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(Companies_Title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (10, 0), textcoords = 'offset points')
